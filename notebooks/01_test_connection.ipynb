# %%
import sys
sys.path.append("..")

from src.models.ollama_client import OllamaClient

client = OllamaClient(model_name="llama3.1:8b")
answer = client.generate("In one sentence, what is a multi-hop question in QA?")
print(answer)
# Out:
# A multi-hop question in Question Answering (QA) refers to a query that requires the model to retrieve and combine information from multiple sources or entities to arrive at an accurate answer, often involving complex reasoning and inference.
